# %% [markdown]
# <a href="https://colab.research.google.com/github/Marina4ij/DS_1_Marina/blob/main/_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Создаем пустой список
squares = []

# Используем цикл for для перебора чисел от 1 до 10 включительно
# range(1, 11) генерирует числа от 1 до 10
for i in range(1, 11):
    # Вычисляем квадрат числа (i ** 2) и добавляем его в список
    squares.append(i ** 2)

# Выводим полученный список на экран
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# Используя цикл, создан список, содержащий квадраты всех целых чисел от 1 до 10, и выведит его на экран, 2 способа

# %%
squares = [i ** 2 for i in range(1, 11)]
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# второй вариант решения
